# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 938us/sample - loss: 255.5957 - y1_output_loss: 114.0397 - y2_output_loss: 139.2628 - y1_output_root_mean_squared_error: 10.7272 - y2_output_root_mean_squared_error: 11.8542 - val_loss: 51.9694 - val_y1_output_loss: 18.4280 - val_y2_output_loss: 32.0624 - val_y1_output_root_mean_squared_error: 4.3564 - val_y2_output_root_mean_squared_error: 5.7438
# Epoch 2/500
# 614/614 [==============================] - 0s 145us/sample - loss: 32.0904 - y1_output_loss: 12.8212 - y2_output_loss: 19.3295 - y1_output_root_mean_squared_error: 3.5635 - y2_output_root_mean_squared_error: 4.4036 - val_loss: 28.6362 - val_y1_output_loss: 12.8574 - val_y2_output_loss: 15.3221 - val_y1_output_root_mean_squared_error: 3.5988 - val_y2_output_root_mean_squared_error: 3.9604
# Epoch 3/500
# 614/614 [==============================] - 0s 128us/sample - loss: 26.3544 - y1_output_loss: 10.3284 - y2_output_loss: 16.1838 - y1_output_root_mean_squared_error: 3.1896 - y2_output_root_mean_squared_error: 4.0226 - val_loss: 35.3828 - val_y1_output_loss: 13.5008 - val_y2_output_loss: 21.2644 - val_y1_output_root_mean_squared_error: 3.7037 - val_y2_output_root_mean_squared_error: 4.6546
# Epoch 4/500
# 614/614 [==============================] - 0s 124us/sample - loss: 24.4069 - y1_output_loss: 9.7786 - y2_output_loss: 14.4021 - y1_output_root_mean_squared_error: 3.1420 - y2_output_root_mean_squared_error: 3.8124 - val_loss: 20.7405 - val_y1_output_loss: 8.6835 - val_y2_output_loss: 11.4259 - val_y1_output_root_mean_squared_error: 2.9845 - val_y2_output_root_mean_squared_error: 3.4400
# Epoch 5/500
# 614/614 [==============================] - 0s 124us/sample - loss: 28.9617 - y1_output_loss: 9.8151 - y2_output_loss: 18.9680 - y1_output_root_mean_squared_error: 3.1447 - y2_output_root_mean_squared_error: 4.3672 - val_loss: 43.2910 - val_y1_output_loss: 12.5273 - val_y2_output_loss: 29.9936 - val_y1_output_root_mean_squared_error: 3.5659 - val_y2_output_root_mean_squared_error: 5.5295
# Epoch 6/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.4839 - y1_output_loss: 9.1295 - y2_output_loss: 14.1517 - y1_output_root_mean_squared_error: 3.0037 - y2_output_root_mean_squared_error: 3.6690 - val_loss: 77.1721 - val_y1_output_loss: 12.2509 - val_y2_output_loss: 62.8399 - val_y1_output_root_mean_squared_error: 3.5508 - val_y2_output_root_mean_squared_error: 8.0352
# Epoch 7/500
# 614/614 [==============================] - 0s 129us/sample - loss: 25.7374 - y1_output_loss: 9.8868 - y2_output_loss: 16.1996 - y1_output_root_mean_squared_error: 3.0913 - y2_output_root_mean_squared_error: 4.0226 - val_loss: 30.9969 - val_y1_output_loss: 8.2731 - val_y2_output_loss: 22.0263 - val_y1_output_root_mean_squared_error: 2.9112 - val_y2_output_root_mean_squared_error: 4.7457
# Epoch 8/500
# 614/614 [==============================] - 0s 122us/sample - loss: 20.5492 - y1_output_loss: 8.1157 - y2_output_loss: 12.2725 - y1_output_root_mean_squared_error: 2.8584 - y2_output_root_mean_squared_error: 3.5184 - val_loss: 20.2996 - val_y1_output_loss: 9.0386 - val_y2_output_loss: 10.6629 - val_y1_output_root_mean_squared_error: 3.0444 - val_y2_output_root_mean_squared_error: 3.3213
# Epoch 9/500
# 614/614 [==============================] - 0s 122us/sample - loss: 21.7722 - y1_output_loss: 8.4200 - y2_output_loss: 13.6171 - y1_output_root_mean_squared_error: 2.8842 - y2_output_root_mean_squared_error: 3.6679 - val_loss: 24.3074 - val_y1_output_loss: 7.6601 - val_y2_output_loss: 16.1100 - val_y1_output_root_mean_squared_error: 2.8002 - val_y2_output_root_mean_squared_error: 4.0579
# Epoch 10/500
# 614/614 [==============================] - 0s 122us/sample - loss: 20.4858 - y1_output_loss: 8.1253 - y2_output_loss: 12.5182 - y1_output_root_mean_squared_error: 2.8439 - y2_output_root_mean_squared_error: 3.5211 - val_loss: 33.8843 - val_y1_output_loss: 9.6195 - val_y2_output_loss: 23.4029 - val_y1_output_root_mean_squared_error: 3.1422 - val_y2_output_root_mean_squared_error: 4.9001
# Epoch 11/500
# 614/614 [==============================] - 0s 127us/sample - loss: 22.1160 - y1_output_loss: 8.2995 - y2_output_loss: 13.7734 - y1_output_root_mean_squared_error: 2.8912 - y2_output_root_mean_squared_error: 3.7090 - val_loss: 18.9264 - val_y1_output_loss: 7.9504 - val_y2_output_loss: 10.3926 - val_y1_output_root_mean_squared_error: 2.8623 - val_y2_output_root_mean_squared_error: 3.2762
# Epoch 12/500
# 614/614 [==============================] - 0s 123us/sample - loss: 20.4876 - y1_output_loss: 7.7881 - y2_output_loss: 12.6716 - y1_output_root_mean_squared_error: 2.7942 - y2_output_root_mean_squared_error: 3.5609 - val_loss: 18.4586 - val_y1_output_loss: 7.4196 - val_y2_output_loss: 10.5444 - val_y1_output_root_mean_squared_error: 2.7602 - val_y2_output_root_mean_squared_error: 3.2924
# Epoch 13/500
# 614/614 [==============================] - 0s 122us/sample - loss: 19.8720 - y1_output_loss: 7.7019 - y2_output_loss: 12.1617 - y1_output_root_mean_squared_error: 2.7816 - y2_output_root_mean_squared_error: 3.4835 - val_loss: 24.3048 - val_y1_output_loss: 8.2486 - val_y2_output_loss: 15.5577 - val_y1_output_root_mean_squared_error: 2.9012 - val_y2_output_root_mean_squared_error: 3.9860
# Epoch 14/500
# 614/614 [==============================] - 0s 124us/sample - loss: 20.8386 - y1_output_loss: 8.0068 - y2_output_loss: 12.7544 - y1_output_root_mean_squared_error: 2.8388 - y2_output_root_mean_squared_error: 3.5749 - val_loss: 17.7649 - val_y1_output_loss: 6.8277 - val_y2_output_loss: 10.5136 - val_y1_output_root_mean_squared_error: 2.6433 - val_y2_output_root_mean_squared_error: 3.2830
# Epoch 15/500
# 614/614 [==============================] - 0s 123us/sample - loss: 17.9424 - y1_output_loss: 7.0244 - y2_output_loss: 10.9810 - y1_output_root_mean_squared_error: 2.6497 - y2_output_root_mean_squared_error: 3.3047 - val_loss: 16.9188 - val_y1_output_loss: 6.8975 - val_y2_output_loss: 9.4413 - val_y1_output_root_mean_squared_error: 2.6710 - val_y2_output_root_mean_squared_error: 3.1280
# Epoch 16/500
# 614/614 [==============================] - 0s 134us/sample - loss: 18.4304 - y1_output_loss: 7.1342 - y2_output_loss: 11.3162 - y1_output_root_mean_squared_error: 2.6682 - y2_output_root_mean_squared_error: 3.3632 - val_loss: 21.3162 - val_y1_output_loss: 8.7625 - val_y2_output_loss: 11.9574 - val_y1_output_root_mean_squared_error: 2.9998 - val_y2_output_root_mean_squared_error: 3.5096
# Epoch 17/500
# 614/614 [==============================] - 0s 122us/sample - loss: 18.2799 - y1_output_loss: 7.3658 - y2_output_loss: 10.8574 - y1_output_root_mean_squared_error: 2.7152 - y2_output_root_mean_squared_error: 3.3026 - val_loss: 24.4829 - val_y1_output_loss: 9.6263 - val_y2_output_loss: 14.4175 - val_y1_output_root_mean_squared_error: 3.1247 - val_y2_output_root_mean_squared_error: 3.8366
# Epoch 18/500
# 614/614 [==============================] - 0s 123us/sample - loss: 19.7880 - y1_output_loss: 7.1614 - y2_output_loss: 12.6840 - y1_output_root_mean_squared_error: 2.6772 - y2_output_root_mean_squared_error: 3.5525 - val_loss: 35.4437 - val_y1_output_loss: 11.5114 - val_y2_output_loss: 23.0873 - val_y1_output_root_mean_squared_error: 3.4364 - val_y2_output_root_mean_squared_error: 4.8616
# Epoch 19/500
# 614/614 [==============================] - 0s 123us/sample - loss: 19.0993 - y1_output_loss: 7.0852 - y2_output_loss: 12.0202 - y1_output_root_mean_squared_error: 2.6713 - y2_output_root_mean_squared_error: 3.4588 - val_loss: 16.1253 - val_y1_output_loss: 6.4695 - val_y2_output_loss: 9.1271 - val_y1_output_root_mean_squared_error: 2.5827 - val_y2_output_root_mean_squared_error: 3.0749
# Epoch 20/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.8949 - y1_output_loss: 6.9865 - y2_output_loss: 11.0124 - y1_output_root_mean_squared_error: 2.6296 - y2_output_root_mean_squared_error: 3.3136 - val_loss: 39.3512 - val_y1_output_loss: 10.4319 - val_y2_output_loss: 28.2052 - val_y1_output_root_mean_squared_error: 3.2577 - val_y2_output_root_mean_squared_error: 5.3608
# Epoch 21/500
# 614/614 [==============================] - 0s 122us/sample - loss: 15.9125 - y1_output_loss: 5.9731 - y2_output_loss: 9.9542 - y1_output_root_mean_squared_error: 2.4278 - y2_output_root_mean_squared_error: 3.1652 - val_loss: 25.7283 - val_y1_output_loss: 10.0374 - val_y2_output_loss: 15.0869 - val_y1_output_root_mean_squared_error: 3.2018 - val_y2_output_root_mean_squared_error: 3.9340
# Epoch 22/500
# 614/614 [==============================] - 0s 121us/sample - loss: 16.3972 - y1_output_loss: 6.1334 - y2_output_loss: 10.5718 - y1_output_root_mean_squared_error: 2.4729 - y2_output_root_mean_squared_error: 3.2066 - val_loss: 122.5702 - val_y1_output_loss: 15.8689 - val_y2_output_loss: 104.3341 - val_y1_output_root_mean_squared_error: 4.0250 - val_y2_output_root_mean_squared_error: 10.3136
# Epoch 23/500
# 614/614 [==============================] - 0s 123us/sample - loss: 20.5739 - y1_output_loss: 6.7414 - y2_output_loss: 13.6835 - y1_output_root_mean_squared_error: 2.6080 - y2_output_root_mean_squared_error: 3.7111 - val_loss: 14.2685 - val_y1_output_loss: 4.7894 - val_y2_output_loss: 9.0647 - val_y1_output_root_mean_squared_error: 2.2223 - val_y2_output_root_mean_squared_error: 3.0545
# Epoch 24/500
# 614/614 [==============================] - 0s 127us/sample - loss: 22.4818 - y1_output_loss: 7.4629 - y2_output_loss: 14.8628 - y1_output_root_mean_squared_error: 2.7420 - y2_output_root_mean_squared_error: 3.8682 - val_loss: 21.9011 - val_y1_output_loss: 8.2379 - val_y2_output_loss: 13.0015 - val_y1_output_root_mean_squared_error: 2.9153 - val_y2_output_root_mean_squared_error: 3.6609
# Epoch 25/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.8214 - y1_output_loss: 5.0987 - y2_output_loss: 7.6412 - y1_output_root_mean_squared_error: 2.2650 - y2_output_root_mean_squared_error: 2.7733 - val_loss: 11.1883 - val_y1_output_loss: 4.2875 - val_y2_output_loss: 6.5154 - val_y1_output_root_mean_squared_error: 2.1054 - val_y2_output_root_mean_squared_error: 2.5992
# Epoch 26/500
# 614/614 [==============================] - 0s 124us/sample - loss: 16.3559 - y1_output_loss: 5.5775 - y2_output_loss: 10.7847 - y1_output_root_mean_squared_error: 2.3534 - y2_output_root_mean_squared_error: 3.2890 - val_loss: 15.0758 - val_y1_output_loss: 5.3654 - val_y2_output_loss: 9.2332 - val_y1_output_root_mean_squared_error: 2.3558 - val_y2_output_root_mean_squared_error: 3.0864
# Epoch 27/500
# 614/614 [==============================] - 0s 123us/sample - loss: 11.6709 - y1_output_loss: 4.4675 - y2_output_loss: 7.1044 - y1_output_root_mean_squared_error: 2.1219 - y2_output_root_mean_squared_error: 2.6774 - val_loss: 10.2944 - val_y1_output_loss: 3.9495 - val_y2_output_loss: 6.0051 - val_y1_output_root_mean_squared_error: 2.0187 - val_y2_output_root_mean_squared_error: 2.4938
# Epoch 28/500
# 614/614 [==============================] - 0s 123us/sample - loss: 12.9882 - y1_output_loss: 4.7531 - y2_output_loss: 8.1209 - y1_output_root_mean_squared_error: 2.1905 - y2_output_root_mean_squared_error: 2.8618 - val_loss: 10.7081 - val_y1_output_loss: 3.9777 - val_y2_output_loss: 6.4006 - val_y1_output_root_mean_squared_error: 2.0195 - val_y2_output_root_mean_squared_error: 2.5748
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.8090 - y1_output_loss: 4.9544 - y2_output_loss: 8.0509 - y1_output_root_mean_squared_error: 2.2103 - y2_output_root_mean_squared_error: 2.8149 - val_loss: 9.8510 - val_y1_output_loss: 4.0659 - val_y2_output_loss: 5.4539 - val_y1_output_root_mean_squared_error: 2.0502 - val_y2_output_root_mean_squared_error: 2.3765
# Epoch 30/500
# 614/614 [==============================] - 0s 125us/sample - loss: 17.3768 - y1_output_loss: 5.7240 - y2_output_loss: 11.7053 - y1_output_root_mean_squared_error: 2.3886 - y2_output_root_mean_squared_error: 3.4163 - val_loss: 9.3354 - val_y1_output_loss: 3.4812 - val_y2_output_loss: 5.5240 - val_y1_output_root_mean_squared_error: 1.8976 - val_y2_output_root_mean_squared_error: 2.3947
# Epoch 31/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.9096 - y1_output_loss: 4.1765 - y2_output_loss: 6.8050 - y1_output_root_mean_squared_error: 2.0309 - y2_output_root_mean_squared_error: 2.6048 - val_loss: 16.0367 - val_y1_output_loss: 5.6034 - val_y2_output_loss: 9.9684 - val_y1_output_root_mean_squared_error: 2.4060 - val_y2_output_root_mean_squared_error: 3.2013
# Epoch 32/500
# 614/614 [==============================] - 0s 122us/sample - loss: 10.8293 - y1_output_loss: 3.9436 - y2_output_loss: 6.8042 - y1_output_root_mean_squared_error: 1.9909 - y2_output_root_mean_squared_error: 2.6202 - val_loss: 8.5983 - val_y1_output_loss: 3.0779 - val_y2_output_loss: 5.2399 - val_y1_output_root_mean_squared_error: 1.7811 - val_y2_output_root_mean_squared_error: 2.3294
# Epoch 33/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.9961 - y1_output_loss: 3.6552 - y2_output_loss: 6.4338 - y1_output_root_mean_squared_error: 1.9131 - y2_output_root_mean_squared_error: 2.5172 - val_loss: 34.0627 - val_y1_output_loss: 7.5894 - val_y2_output_loss: 25.5306 - val_y1_output_root_mean_squared_error: 2.7942 - val_y2_output_root_mean_squared_error: 5.1240
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.4890 - y1_output_loss: 4.2449 - y2_output_loss: 8.2470 - y1_output_root_mean_squared_error: 2.0623 - y2_output_root_mean_squared_error: 2.8698 - val_loss: 10.5594 - val_y1_output_loss: 3.6312 - val_y2_output_loss: 6.6033 - val_y1_output_root_mean_squared_error: 1.9386 - val_y2_output_root_mean_squared_error: 2.6079
# Epoch 35/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.7152 - y1_output_loss: 3.6173 - y2_output_loss: 6.0494 - y1_output_root_mean_squared_error: 1.8998 - y2_output_root_mean_squared_error: 2.4710 - val_loss: 7.6535 - val_y1_output_loss: 2.6581 - val_y2_output_loss: 4.7597 - val_y1_output_root_mean_squared_error: 1.6514 - val_y2_output_root_mean_squared_error: 2.2195
# Epoch 36/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.1504 - y1_output_loss: 3.5193 - y2_output_loss: 6.7238 - y1_output_root_mean_squared_error: 1.8708 - y2_output_root_mean_squared_error: 2.5788 - val_loss: 7.8247 - val_y1_output_loss: 3.1701 - val_y2_output_loss: 4.3722 - val_y1_output_root_mean_squared_error: 1.8131 - val_y2_output_root_mean_squared_error: 2.1301
# Epoch 37/500
# 614/614 [==============================] - 0s 126us/sample - loss: 9.6195 - y1_output_loss: 3.1510 - y2_output_loss: 6.4224 - y1_output_root_mean_squared_error: 1.7830 - y2_output_root_mean_squared_error: 2.5378 - val_loss: 7.5433 - val_y1_output_loss: 2.6317 - val_y2_output_loss: 4.6416 - val_y1_output_root_mean_squared_error: 1.6516 - val_y2_output_root_mean_squared_error: 2.1944
# Epoch 38/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.0233 - y1_output_loss: 3.9375 - y2_output_loss: 8.0293 - y1_output_root_mean_squared_error: 1.9808 - y2_output_root_mean_squared_error: 2.8460 - val_loss: 14.1115 - val_y1_output_loss: 3.3284 - val_y2_output_loss: 10.4200 - val_y1_output_root_mean_squared_error: 1.8554 - val_y2_output_root_mean_squared_error: 3.2663
# Epoch 39/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.1440 - y1_output_loss: 3.2401 - y2_output_loss: 5.9654 - y1_output_root_mean_squared_error: 1.7996 - y2_output_root_mean_squared_error: 2.4301 - val_loss: 18.2520 - val_y1_output_loss: 5.7948 - val_y2_output_loss: 11.8976 - val_y1_output_root_mean_squared_error: 2.4490 - val_y2_output_root_mean_squared_error: 3.5007
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.2796 - y1_output_loss: 3.1434 - y2_output_loss: 6.0624 - y1_output_root_mean_squared_error: 1.7794 - y2_output_root_mean_squared_error: 2.4725 - val_loss: 7.4754 - val_y1_output_loss: 2.1782 - val_y2_output_loss: 5.0510 - val_y1_output_root_mean_squared_error: 1.4988 - val_y2_output_root_mean_squared_error: 2.2867
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.7220 - y1_output_loss: 3.1459 - y2_output_loss: 6.7496 - y1_output_root_mean_squared_error: 1.7748 - y2_output_root_mean_squared_error: 2.5636 - val_loss: 16.4825 - val_y1_output_loss: 3.2113 - val_y2_output_loss: 13.0455 - val_y1_output_root_mean_squared_error: 1.7970 - val_y2_output_root_mean_squared_error: 3.6405
# Epoch 42/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.1628 - y1_output_loss: 3.5606 - y2_output_loss: 8.6471 - y1_output_root_mean_squared_error: 1.8914 - y2_output_root_mean_squared_error: 2.9301 - val_loss: 8.2811 - val_y1_output_loss: 2.5642 - val_y2_output_loss: 5.4355 - val_y1_output_root_mean_squared_error: 1.6310 - val_y2_output_root_mean_squared_error: 2.3708
# Epoch 43/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.4353 - y1_output_loss: 2.6225 - y2_output_loss: 4.7602 - y1_output_root_mean_squared_error: 1.6262 - y2_output_root_mean_squared_error: 2.1888 - val_loss: 8.4308 - val_y1_output_loss: 2.6761 - val_y2_output_loss: 5.5779 - val_y1_output_root_mean_squared_error: 1.6457 - val_y2_output_root_mean_squared_error: 2.3921
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.5682 - y1_output_loss: 2.7988 - y2_output_loss: 5.7960 - y1_output_root_mean_squared_error: 1.6791 - y2_output_root_mean_squared_error: 2.3977 - val_loss: 11.1076 - val_y1_output_loss: 2.4364 - val_y2_output_loss: 8.3696 - val_y1_output_root_mean_squared_error: 1.5794 - val_y2_output_root_mean_squared_error: 2.9348
# Epoch 45/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.7910 - y1_output_loss: 3.4954 - y2_output_loss: 7.4397 - y1_output_root_mean_squared_error: 1.8613 - y2_output_root_mean_squared_error: 2.7068 - val_loss: 49.5610 - val_y1_output_loss: 14.3326 - val_y2_output_loss: 34.2688 - val_y1_output_root_mean_squared_error: 3.8278 - val_y2_output_root_mean_squared_error: 5.9084
# Epoch 46/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.2679 - y1_output_loss: 2.4135 - y2_output_loss: 4.8271 - y1_output_root_mean_squared_error: 1.5505 - y2_output_root_mean_squared_error: 2.2054 - val_loss: 12.2701 - val_y1_output_loss: 4.1023 - val_y2_output_loss: 7.7889 - val_y1_output_root_mean_squared_error: 2.0608 - val_y2_output_root_mean_squared_error: 2.8325
# Epoch 47/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.3639 - y1_output_loss: 2.7431 - y2_output_loss: 5.6398 - y1_output_root_mean_squared_error: 1.6492 - y2_output_root_mean_squared_error: 2.3757 - val_loss: 13.2342 - val_y1_output_loss: 4.4851 - val_y2_output_loss: 8.4015 - val_y1_output_root_mean_squared_error: 2.1508 - val_y2_output_root_mean_squared_error: 2.9340
# Epoch 48/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.2540 - y1_output_loss: 2.2168 - y2_output_loss: 4.9769 - y1_output_root_mean_squared_error: 1.4948 - y2_output_root_mean_squared_error: 2.2404 - val_loss: 6.0145 - val_y1_output_loss: 1.8006 - val_y2_output_loss: 4.0391 - val_y1_output_root_mean_squared_error: 1.3562 - val_y2_output_root_mean_squared_error: 2.0434
# Epoch 49/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.4506 - y1_output_loss: 2.3324 - y2_output_loss: 5.0608 - y1_output_root_mean_squared_error: 1.5316 - y2_output_root_mean_squared_error: 2.2594 - val_loss: 6.5928 - val_y1_output_loss: 2.1138 - val_y2_output_loss: 4.3326 - val_y1_output_root_mean_squared_error: 1.4597 - val_y2_output_root_mean_squared_error: 2.1124
# Epoch 50/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6644 - y1_output_loss: 2.2312 - y2_output_loss: 4.3763 - y1_output_root_mean_squared_error: 1.4997 - y2_output_root_mean_squared_error: 2.1013 - val_loss: 5.8370 - val_y1_output_loss: 1.7588 - val_y2_output_loss: 3.8748 - val_y1_output_root_mean_squared_error: 1.3493 - val_y2_output_root_mean_squared_error: 2.0041
# Epoch 51/500
# 614/614 [==============================] - 0s 123us/sample - loss: 7.1880 - y1_output_loss: 2.2777 - y2_output_loss: 4.8475 - y1_output_root_mean_squared_error: 1.5148 - y2_output_root_mean_squared_error: 2.2121 - val_loss: 6.5008 - val_y1_output_loss: 2.2239 - val_y2_output_loss: 4.1104 - val_y1_output_root_mean_squared_error: 1.5024 - val_y2_output_root_mean_squared_error: 2.0600
# Epoch 52/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.4277 - y1_output_loss: 2.3721 - y2_output_loss: 5.0362 - y1_output_root_mean_squared_error: 1.5442 - y2_output_root_mean_squared_error: 2.2457 - val_loss: 5.7364 - val_y1_output_loss: 1.8119 - val_y2_output_loss: 3.7183 - val_y1_output_root_mean_squared_error: 1.3707 - val_y2_output_root_mean_squared_error: 1.9641
# Epoch 53/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.2878 - y1_output_loss: 2.1719 - y2_output_loss: 4.0995 - y1_output_root_mean_squared_error: 1.4776 - y2_output_root_mean_squared_error: 2.0259 - val_loss: 5.9210 - val_y1_output_loss: 1.9731 - val_y2_output_loss: 3.8118 - val_y1_output_root_mean_squared_error: 1.4141 - val_y2_output_root_mean_squared_error: 1.9802
# Epoch 54/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.6451 - y1_output_loss: 2.4310 - y2_output_loss: 5.1722 - y1_output_root_mean_squared_error: 1.5607 - y2_output_root_mean_squared_error: 2.2824 - val_loss: 9.7540 - val_y1_output_loss: 3.2283 - val_y2_output_loss: 6.1955 - val_y1_output_root_mean_squared_error: 1.8303 - val_y2_output_root_mean_squared_error: 2.5306
# Epoch 55/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.4647 - y1_output_loss: 2.9656 - y2_output_loss: 6.4237 - y1_output_root_mean_squared_error: 1.7278 - y2_output_root_mean_squared_error: 2.5455 - val_loss: 5.3884 - val_y1_output_loss: 1.5769 - val_y2_output_loss: 3.6197 - val_y1_output_root_mean_squared_error: 1.2764 - val_y2_output_root_mean_squared_error: 1.9388
# Epoch 56/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.2714 - y1_output_loss: 1.7476 - y2_output_loss: 3.5127 - y1_output_root_mean_squared_error: 1.3210 - y2_output_root_mean_squared_error: 1.8778 - val_loss: 8.0215 - val_y1_output_loss: 2.0086 - val_y2_output_loss: 5.7763 - val_y1_output_root_mean_squared_error: 1.4406 - val_y2_output_root_mean_squared_error: 2.4385
# Epoch 57/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.9419 - y1_output_loss: 1.9193 - y2_output_loss: 4.0069 - y1_output_root_mean_squared_error: 1.3828 - y2_output_root_mean_squared_error: 2.0075 - val_loss: 7.8060 - val_y1_output_loss: 1.9779 - val_y2_output_loss: 5.5975 - val_y1_output_root_mean_squared_error: 1.4317 - val_y2_output_root_mean_squared_error: 2.3992
# Epoch 58/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.6320 - y1_output_loss: 2.4021 - y2_output_loss: 6.2098 - y1_output_root_mean_squared_error: 1.5531 - y2_output_root_mean_squared_error: 2.4940 - val_loss: 8.6127 - val_y1_output_loss: 1.4103 - val_y2_output_loss: 6.9740 - val_y1_output_root_mean_squared_error: 1.1998 - val_y2_output_root_mean_squared_error: 2.6783
# Epoch 59/500
# 614/614 [==============================] - 0s 126us/sample - loss: 7.1076 - y1_output_loss: 2.0628 - y2_output_loss: 4.9933 - y1_output_root_mean_squared_error: 1.4403 - y2_output_root_mean_squared_error: 2.2435 - val_loss: 5.2486 - val_y1_output_loss: 1.6020 - val_y2_output_loss: 3.4702 - val_y1_output_root_mean_squared_error: 1.2869 - val_y2_output_root_mean_squared_error: 1.8954
# Epoch 60/500
# 614/614 [==============================] - 0s 123us/sample - loss: 6.3272 - y1_output_loss: 2.0264 - y2_output_loss: 4.4288 - y1_output_root_mean_squared_error: 1.4234 - y2_output_root_mean_squared_error: 2.0739 - val_loss: 19.5472 - val_y1_output_loss: 3.2248 - val_y2_output_loss: 16.0438 - val_y1_output_root_mean_squared_error: 1.7925 - val_y2_output_root_mean_squared_error: 4.0416
# Epoch 61/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.4139 - y1_output_loss: 1.5479 - y2_output_loss: 3.8393 - y1_output_root_mean_squared_error: 1.2462 - y2_output_root_mean_squared_error: 1.9649 - val_loss: 7.5034 - val_y1_output_loss: 2.0158 - val_y2_output_loss: 5.2707 - val_y1_output_root_mean_squared_error: 1.4452 - val_y2_output_root_mean_squared_error: 2.3270
# Epoch 62/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.9168 - y1_output_loss: 1.5565 - y2_output_loss: 3.3733 - y1_output_root_mean_squared_error: 1.2497 - y2_output_root_mean_squared_error: 1.8317 - val_loss: 12.2445 - val_y1_output_loss: 2.1045 - val_y2_output_loss: 9.9836 - val_y1_output_root_mean_squared_error: 1.4420 - val_y2_output_root_mean_squared_error: 3.1883
# Epoch 63/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.8143 - y1_output_loss: 1.5504 - y2_output_loss: 3.2894 - y1_output_root_mean_squared_error: 1.2341 - y2_output_root_mean_squared_error: 1.8142 - val_loss: 4.3425 - val_y1_output_loss: 1.1320 - val_y2_output_loss: 3.1096 - val_y1_output_root_mean_squared_error: 1.0615 - val_y2_output_root_mean_squared_error: 1.7932
# Epoch 64/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.1649 - y1_output_loss: 1.9382 - y2_output_loss: 4.2152 - y1_output_root_mean_squared_error: 1.3915 - y2_output_root_mean_squared_error: 2.0563 - val_loss: 9.3168 - val_y1_output_loss: 3.1478 - val_y2_output_loss: 5.9338 - val_y1_output_root_mean_squared_error: 1.8000 - val_y2_output_root_mean_squared_error: 2.4652
# Epoch 65/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.8888 - y1_output_loss: 1.4681 - y2_output_loss: 3.3797 - y1_output_root_mean_squared_error: 1.2157 - y2_output_root_mean_squared_error: 1.8469 - val_loss: 6.6624 - val_y1_output_loss: 1.9281 - val_y2_output_loss: 4.5267 - val_y1_output_root_mean_squared_error: 1.4126 - val_y2_output_root_mean_squared_error: 2.1603
# Epoch 66/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.3879 - y1_output_loss: 1.3556 - y2_output_loss: 3.0515 - y1_output_root_mean_squared_error: 1.1613 - y2_output_root_mean_squared_error: 1.7434 - val_loss: 6.5467 - val_y1_output_loss: 1.8225 - val_y2_output_loss: 4.5449 - val_y1_output_root_mean_squared_error: 1.3729 - val_y2_output_root_mean_squared_error: 2.1591
# Epoch 67/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.8041 - y1_output_loss: 1.7795 - y2_output_loss: 5.0297 - y1_output_root_mean_squared_error: 1.3332 - y2_output_root_mean_squared_error: 2.2420 - val_loss: 18.1767 - val_y1_output_loss: 5.8610 - val_y2_output_loss: 11.6938 - val_y1_output_root_mean_squared_error: 2.4664 - val_y2_output_root_mean_squared_error: 3.4776
# Epoch 68/500
# 614/614 [==============================] - 0s 121us/sample - loss: 6.6832 - y1_output_loss: 2.0219 - y2_output_loss: 4.6442 - y1_output_root_mean_squared_error: 1.4190 - y2_output_root_mean_squared_error: 2.1609 - val_loss: 4.9725 - val_y1_output_loss: 1.4015 - val_y2_output_loss: 3.3972 - val_y1_output_root_mean_squared_error: 1.2051 - val_y2_output_root_mean_squared_error: 1.8762
# Epoch 69/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.0963 - y1_output_loss: 1.5813 - y2_output_loss: 4.5432 - y1_output_root_mean_squared_error: 1.2628 - y2_output_root_mean_squared_error: 2.1217 - val_loss: 10.5328 - val_y1_output_loss: 1.3237 - val_y2_output_loss: 8.9471 - val_y1_output_root_mean_squared_error: 1.1552 - val_y2_output_root_mean_squared_error: 3.0329
# Epoch 70/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.4219 - y1_output_loss: 1.2340 - y2_output_loss: 3.1827 - y1_output_root_mean_squared_error: 1.1135 - y2_output_root_mean_squared_error: 1.7838 - val_loss: 6.6516 - val_y1_output_loss: 1.3615 - val_y2_output_loss: 5.1238 - val_y1_output_root_mean_squared_error: 1.1705 - val_y2_output_root_mean_squared_error: 2.2982
# Epoch 71/500
# 614/614 [==============================] - 0s 120us/sample - loss: 9.4535 - y1_output_loss: 2.7827 - y2_output_loss: 6.6093 - y1_output_root_mean_squared_error: 1.6736 - y2_output_root_mean_squared_error: 2.5792 - val_loss: 4.9600 - val_y1_output_loss: 0.8500 - val_y2_output_loss: 3.9682 - val_y1_output_root_mean_squared_error: 0.9335 - val_y2_output_root_mean_squared_error: 2.0220
# Epoch 72/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.2047 - y1_output_loss: 1.2299 - y2_output_loss: 2.9606 - y1_output_root_mean_squared_error: 1.1139 - y2_output_root_mean_squared_error: 1.7216 - val_loss: 9.3588 - val_y1_output_loss: 2.0073 - val_y2_output_loss: 7.2517 - val_y1_output_root_mean_squared_error: 1.4007 - val_y2_output_root_mean_squared_error: 2.7197
# Epoch 73/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.9512 - y1_output_loss: 0.9854 - y2_output_loss: 2.9404 - y1_output_root_mean_squared_error: 0.9925 - y2_output_root_mean_squared_error: 1.7223 - val_loss: 3.7881 - val_y1_output_loss: 0.7547 - val_y2_output_loss: 2.9165 - val_y1_output_root_mean_squared_error: 0.8794 - val_y2_output_root_mean_squared_error: 1.7363
# Epoch 74/500
# 614/614 [==============================] - 0s 121us/sample - loss: 4.8623 - y1_output_loss: 1.3460 - y2_output_loss: 3.5087 - y1_output_root_mean_squared_error: 1.1615 - y2_output_root_mean_squared_error: 1.8744 - val_loss: 3.8397 - val_y1_output_loss: 0.7380 - val_y2_output_loss: 2.9730 - val_y1_output_root_mean_squared_error: 0.8695 - val_y2_output_root_mean_squared_error: 1.7560
# Epoch 75/500
# 614/614 [==============================] - 0s 122us/sample - loss: 21.0891 - y1_output_loss: 6.9168 - y2_output_loss: 14.0868 - y1_output_root_mean_squared_error: 2.6272 - y2_output_root_mean_squared_error: 3.7665 - val_loss: 15.2465 - val_y1_output_loss: 5.0983 - val_y2_output_loss: 9.6558 - val_y1_output_root_mean_squared_error: 2.2993 - val_y2_output_root_mean_squared_error: 3.1559
# Epoch 76/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.5358 - y1_output_loss: 1.3675 - y2_output_loss: 3.3861 - y1_output_root_mean_squared_error: 1.1485 - y2_output_root_mean_squared_error: 1.7935 - val_loss: 27.1556 - val_y1_output_loss: 7.4055 - val_y2_output_loss: 19.0740 - val_y1_output_root_mean_squared_error: 2.7460 - val_y2_output_root_mean_squared_error: 4.4289
# Epoch 77/500
# 614/614 [==============================] - 0s 120us/sample - loss: 5.0195 - y1_output_loss: 1.4579 - y2_output_loss: 3.5565 - y1_output_root_mean_squared_error: 1.2082 - y2_output_root_mean_squared_error: 1.8868 - val_loss: 4.6039 - val_y1_output_loss: 1.0961 - val_y2_output_loss: 3.3593 - val_y1_output_root_mean_squared_error: 1.0669 - val_y2_output_root_mean_squared_error: 1.8616
# Epoch 78/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.3482 - y1_output_loss: 0.8583 - y2_output_loss: 2.5551 - y1_output_root_mean_squared_error: 0.9207 - y2_output_root_mean_squared_error: 1.5813 - val_loss: 3.5322 - val_y1_output_loss: 0.6544 - val_y2_output_loss: 2.7749 - val_y1_output_root_mean_squared_error: 0.8128 - val_y2_output_root_mean_squared_error: 1.6946
# Epoch 79/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.6843 - y1_output_loss: 1.2489 - y2_output_loss: 3.4030 - y1_output_root_mean_squared_error: 1.1221 - y2_output_root_mean_squared_error: 1.8508 - val_loss: 5.3573 - val_y1_output_loss: 0.9574 - val_y2_output_loss: 4.2919 - val_y1_output_root_mean_squared_error: 0.9953 - val_y2_output_root_mean_squared_error: 2.0897
# Epoch 80/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.7411 - y1_output_loss: 1.0133 - y2_output_loss: 2.6960 - y1_output_root_mean_squared_error: 1.0099 - y2_output_root_mean_squared_error: 1.6496 - val_loss: 3.8607 - val_y1_output_loss: 1.0581 - val_y2_output_loss: 2.6853 - val_y1_output_root_mean_squared_error: 1.0450 - val_y2_output_root_mean_squared_error: 1.6639
# Epoch 81/500
# 614/614 [==============================] - 0s 118us/sample - loss: 3.1616 - y1_output_loss: 0.8463 - y2_output_loss: 2.2897 - y1_output_root_mean_squared_error: 0.9237 - y2_output_root_mean_squared_error: 1.5194 - val_loss: 4.4573 - val_y1_output_loss: 0.7699 - val_y2_output_loss: 3.6123 - val_y1_output_root_mean_squared_error: 0.8911 - val_y2_output_root_mean_squared_error: 1.9139
# Epoch 82/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.4357 - y1_output_loss: 0.7844 - y2_output_loss: 2.6337 - y1_output_root_mean_squared_error: 0.8883 - y2_output_root_mean_squared_error: 1.6268 - val_loss: 3.4961 - val_y1_output_loss: 0.4830 - val_y2_output_loss: 2.8999 - val_y1_output_root_mean_squared_error: 0.6982 - val_y2_output_root_mean_squared_error: 1.7345
# Epoch 83/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.5619 - y1_output_loss: 0.8139 - y2_output_loss: 2.7200 - y1_output_root_mean_squared_error: 0.9056 - y2_output_root_mean_squared_error: 1.6559 - val_loss: 4.0526 - val_y1_output_loss: 0.5057 - val_y2_output_loss: 3.4168 - val_y1_output_root_mean_squared_error: 0.7138 - val_y2_output_root_mean_squared_error: 1.8823
# Epoch 84/500
# 614/614 [==============================] - 0s 121us/sample - loss: 3.0033 - y1_output_loss: 0.7125 - y2_output_loss: 2.3334 - y1_output_root_mean_squared_error: 0.8478 - y2_output_root_mean_squared_error: 1.5115 - val_loss: 5.8856 - val_y1_output_loss: 0.8037 - val_y2_output_loss: 4.8893 - val_y1_output_root_mean_squared_error: 0.9057 - val_y2_output_root_mean_squared_error: 2.2506
# Epoch 85/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.0537 - y1_output_loss: 0.6820 - y2_output_loss: 2.3492 - y1_output_root_mean_squared_error: 0.8295 - y2_output_root_mean_squared_error: 1.5380 - val_loss: 3.4344 - val_y1_output_loss: 0.5844 - val_y2_output_loss: 2.7424 - val_y1_output_root_mean_squared_error: 0.7783 - val_y2_output_root_mean_squared_error: 1.6819
# Epoch 86/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.5646 - y1_output_loss: 0.6057 - y2_output_loss: 1.9752 - y1_output_root_mean_squared_error: 0.7775 - y2_output_root_mean_squared_error: 1.4001 - val_loss: 6.7529 - val_y1_output_loss: 1.1012 - val_y2_output_loss: 5.5432 - val_y1_output_root_mean_squared_error: 1.0669 - val_y2_output_root_mean_squared_error: 2.3696
# Epoch 87/500
# 614/614 [==============================] - 0s 121us/sample - loss: 5.9435 - y1_output_loss: 1.8625 - y2_output_loss: 4.0534 - y1_output_root_mean_squared_error: 1.3713 - y2_output_root_mean_squared_error: 2.0157 - val_loss: 3.9443 - val_y1_output_loss: 0.4233 - val_y2_output_loss: 3.3882 - val_y1_output_root_mean_squared_error: 0.6569 - val_y2_output_root_mean_squared_error: 1.8742
# Epoch 88/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.9517 - y1_output_loss: 0.6765 - y2_output_loss: 2.2702 - y1_output_root_mean_squared_error: 0.8155 - y2_output_root_mean_squared_error: 1.5122 - val_loss: 3.8888 - val_y1_output_loss: 0.4019 - val_y2_output_loss: 3.3962 - val_y1_output_root_mean_squared_error: 0.6392 - val_y2_output_root_mean_squared_error: 1.8655
# Epoch 89/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.8056 - y1_output_loss: 0.8561 - y2_output_loss: 2.9215 - y1_output_root_mean_squared_error: 0.9289 - y2_output_root_mean_squared_error: 1.7154 - val_loss: 3.4170 - val_y1_output_loss: 0.4551 - val_y2_output_loss: 2.8431 - val_y1_output_root_mean_squared_error: 0.6829 - val_y2_output_root_mean_squared_error: 1.7177
# Epoch 90/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.6583 - y1_output_loss: 0.6404 - y2_output_loss: 2.0045 - y1_output_root_mean_squared_error: 0.8011 - y2_output_root_mean_squared_error: 1.4201 - val_loss: 3.1575 - val_y1_output_loss: 0.4575 - val_y2_output_loss: 2.6036 - val_y1_output_root_mean_squared_error: 0.6884 - val_y2_output_root_mean_squared_error: 1.6382
# Epoch 91/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.3150 - y1_output_loss: 0.5370 - y2_output_loss: 1.8045 - y1_output_root_mean_squared_error: 0.7358 - y2_output_root_mean_squared_error: 1.3318 - val_loss: 4.5178 - val_y1_output_loss: 0.5752 - val_y2_output_loss: 3.8612 - val_y1_output_root_mean_squared_error: 0.7721 - val_y2_output_root_mean_squared_error: 1.9803
# Epoch 92/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.1638 - y1_output_loss: 1.3813 - y2_output_loss: 3.7768 - y1_output_root_mean_squared_error: 1.1758 - y2_output_root_mean_squared_error: 1.9446 - val_loss: 6.5057 - val_y1_output_loss: 1.8441 - val_y2_output_loss: 4.4642 - val_y1_output_root_mean_squared_error: 1.3833 - val_y2_output_root_mean_squared_error: 2.1429
# Epoch 93/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.3478 - y1_output_loss: 1.0682 - y2_output_loss: 3.2521 - y1_output_root_mean_squared_error: 1.0375 - y2_output_root_mean_squared_error: 1.8087 - val_loss: 3.4527 - val_y1_output_loss: 0.4097 - val_y2_output_loss: 2.9302 - val_y1_output_root_mean_squared_error: 0.6439 - val_y2_output_root_mean_squared_error: 1.7430
# Epoch 94/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1143 - y1_output_loss: 0.7580 - y2_output_loss: 2.3751 - y1_output_root_mean_squared_error: 0.8722 - y2_output_root_mean_squared_error: 1.5342 - val_loss: 11.5738 - val_y1_output_loss: 0.6789 - val_y2_output_loss: 10.5849 - val_y1_output_root_mean_squared_error: 0.8282 - val_y2_output_root_mean_squared_error: 3.2997
# Epoch 95/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.4503 - y1_output_loss: 0.8362 - y2_output_loss: 2.6076 - y1_output_root_mean_squared_error: 0.9176 - y2_output_root_mean_squared_error: 1.6150 - val_loss: 5.0027 - val_y1_output_loss: 0.5410 - val_y2_output_loss: 4.3122 - val_y1_output_root_mean_squared_error: 0.7338 - val_y2_output_root_mean_squared_error: 2.1129
# Epoch 96/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.4015 - y1_output_loss: 0.5430 - y2_output_loss: 1.8556 - y1_output_root_mean_squared_error: 0.7304 - y2_output_root_mean_squared_error: 1.3667 - val_loss: 3.3668 - val_y1_output_loss: 0.5868 - val_y2_output_loss: 2.6865 - val_y1_output_root_mean_squared_error: 0.7611 - val_y2_output_root_mean_squared_error: 1.6696
# Epoch 97/500
# 614/614 [==============================] - 0s 121us/sample - loss: 2.8482 - y1_output_loss: 0.6043 - y2_output_loss: 2.2353 - y1_output_root_mean_squared_error: 0.7801 - y2_output_root_mean_squared_error: 1.4965 - val_loss: 3.2161 - val_y1_output_loss: 0.3776 - val_y2_output_loss: 2.7253 - val_y1_output_root_mean_squared_error: 0.6253 - val_y2_output_root_mean_squared_error: 1.6808
# Epoch 98/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.8798 - y1_output_loss: 0.8013 - y2_output_loss: 3.0842 - y1_output_root_mean_squared_error: 0.8951 - y2_output_root_mean_squared_error: 1.7546 - val_loss: 6.3810 - val_y1_output_loss: 1.3259 - val_y2_output_loss: 4.9180 - val_y1_output_root_mean_squared_error: 1.1716 - val_y2_output_root_mean_squared_error: 2.2379
# Epoch 99/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.7934 - y1_output_loss: 0.5855 - y2_output_loss: 2.2592 - y1_output_root_mean_squared_error: 0.7595 - y2_output_root_mean_squared_error: 1.4888 - val_loss: 12.2588 - val_y1_output_loss: 3.7783 - val_y2_output_loss: 8.2906 - val_y1_output_root_mean_squared_error: 1.9690 - val_y2_output_root_mean_squared_error: 2.8951
# Epoch 100/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.2817 - y1_output_loss: 0.7828 - y2_output_loss: 2.4980 - y1_output_root_mean_squared_error: 0.8850 - y2_output_root_mean_squared_error: 1.5807 - val_loss: 3.4910 - val_y1_output_loss: 0.6369 - val_y2_output_loss: 2.8008 - val_y1_output_root_mean_squared_error: 0.8104 - val_y2_output_root_mean_squared_error: 1.6835
# Epoch 101/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.1469 - y1_output_loss: 0.4702 - y2_output_loss: 1.6574 - y1_output_root_mean_squared_error: 0.6886 - y2_output_root_mean_squared_error: 1.2933 - val_loss: 2.8288 - val_y1_output_loss: 0.4829 - val_y2_output_loss: 2.2570 - val_y1_output_root_mean_squared_error: 0.7079 - val_y2_output_root_mean_squared_error: 1.5257
# Epoch 102/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.2867 - y1_output_loss: 0.4778 - y2_output_loss: 1.7906 - y1_output_root_mean_squared_error: 0.6945 - y2_output_root_mean_squared_error: 1.3433 - val_loss: 3.2507 - val_y1_output_loss: 0.5314 - val_y2_output_loss: 2.6309 - val_y1_output_root_mean_squared_error: 0.7421 - val_y2_output_root_mean_squared_error: 1.6431
# Epoch 103/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.0262 - y1_output_loss: 0.7494 - y2_output_loss: 2.2837 - y1_output_root_mean_squared_error: 0.8667 - y2_output_root_mean_squared_error: 1.5083 - val_loss: 5.1228 - val_y1_output_loss: 0.5263 - val_y2_output_loss: 4.5422 - val_y1_output_root_mean_squared_error: 0.7388 - val_y2_output_root_mean_squared_error: 2.1394
# Epoch 104/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.4315 - y1_output_loss: 0.5697 - y2_output_loss: 1.8469 - y1_output_root_mean_squared_error: 0.7537 - y2_output_root_mean_squared_error: 1.3651 - val_loss: 3.0416 - val_y1_output_loss: 0.3597 - val_y2_output_loss: 2.6077 - val_y1_output_root_mean_squared_error: 0.6077 - val_y2_output_root_mean_squared_error: 1.6347
# Epoch 105/500
# 614/614 [==============================] - 0s 120us/sample - loss: 1.9652 - y1_output_loss: 0.4462 - y2_output_loss: 1.5427 - y1_output_root_mean_squared_error: 0.6707 - y2_output_root_mean_squared_error: 1.2310 - val_loss: 8.4346 - val_y1_output_loss: 0.6576 - val_y2_output_loss: 7.5235 - val_y1_output_root_mean_squared_error: 0.8105 - val_y2_output_root_mean_squared_error: 2.7889
# Epoch 106/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.7502 - y1_output_loss: 0.6669 - y2_output_loss: 2.0591 - y1_output_root_mean_squared_error: 0.8203 - y2_output_root_mean_squared_error: 1.4413 - val_loss: 3.1364 - val_y1_output_loss: 0.6775 - val_y2_output_loss: 2.3693 - val_y1_output_root_mean_squared_error: 0.8384 - val_y2_output_root_mean_squared_error: 1.5600
# Epoch 107/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.1549 - y1_output_loss: 0.5222 - y2_output_loss: 1.6398 - y1_output_root_mean_squared_error: 0.7235 - y2_output_root_mean_squared_error: 1.2773 - val_loss: 4.0536 - val_y1_output_loss: 0.7462 - val_y2_output_loss: 3.2477 - val_y1_output_root_mean_squared_error: 0.8800 - val_y2_output_root_mean_squared_error: 1.8108
# Epoch 108/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.4053 - y1_output_loss: 0.8559 - y2_output_loss: 2.5319 - y1_output_root_mean_squared_error: 0.9272 - y2_output_root_mean_squared_error: 1.5955 - val_loss: 3.5443 - val_y1_output_loss: 0.3704 - val_y2_output_loss: 3.0526 - val_y1_output_root_mean_squared_error: 0.6182 - val_y2_output_root_mean_squared_error: 1.7782
# Epoch 109/500
# 614/614 [==============================] - 0s 120us/sample - loss: 2.6363 - y1_output_loss: 0.5742 - y2_output_loss: 2.0923 - y1_output_root_mean_squared_error: 0.7579 - y2_output_root_mean_squared_error: 1.4360 - val_loss: 8.7203 - val_y1_output_loss: 2.7164 - val_y2_output_loss: 5.9116 - val_y1_output_root_mean_squared_error: 1.6348 - val_y2_output_root_mean_squared_error: 2.4592
# Epoch 110/500
# 614/614 [==============================] - 0s 120us/sample - loss: 1.9967 - y1_output_loss: 0.4854 - y2_output_loss: 1.4964 - y1_output_root_mean_squared_error: 0.6992 - y2_output_root_mean_squared_error: 1.2279 - val_loss: 2.8161 - val_y1_output_loss: 0.4187 - val_y2_output_loss: 2.3206 - val_y1_output_root_mean_squared_error: 0.6554 - val_y2_output_root_mean_squared_error: 1.5448
# Epoch 111/500
# 614/614 [==============================] - 0s 121us/sample - loss: 1.9741 - y1_output_loss: 0.4126 - y2_output_loss: 1.5491 - y1_output_root_mean_squared_error: 0.6437 - y2_output_root_mean_squared_error: 1.2489 - val_loss: 2.5912 - val_y1_output_loss: 0.4304 - val_y2_output_loss: 2.0837 - val_y1_output_root_mean_squared_error: 0.6615 - val_y2_output_root_mean_squared_error: 1.4675
# Epoch 112/500
# 614/614 [==============================] - 0s 120us/sample - loss: 3.5302 - y1_output_loss: 0.8332 - y2_output_loss: 2.6792 - y1_output_root_mean_squared_error: 0.9142 - y2_output_root_mean_squared_error: 1.6415 - val_loss: 4.2931 - val_y1_output_loss: 0.5893 - val_y2_output_loss: 3.6862 - val_y1_output_root_mean_squared_error: 0.7768 - val_y2_output_root_mean_squared_error: 1.9208
# Epoch 113/500
# 614/614 [==============================] - 0s 117us/sample - loss: 2.9220 - y1_output_loss: 0.6400 - y2_output_loss: 2.2786 - y1_output_root_mean_squared_error: 0.8020 - y2_output_root_mean_squared_error: 1.5096 - val_loss: 6.0126 - val_y1_output_loss: 0.4757 - val_y2_output_loss: 5.3279 - val_y1_output_root_mean_squared_error: 0.6978 - val_y2_output_root_mean_squared_error: 2.3507
# Epoch 114/500
# 614/614 [==============================] - 0s 119us/sample - loss: 2.6078 - y1_output_loss: 0.5138 - y2_output_loss: 2.0866 - y1_output_root_mean_squared_error: 0.7124 - y2_output_root_mean_squared_error: 1.4493 - val_loss: 4.6665 - val_y1_output_loss: 0.8958 - val_y2_output_loss: 3.6138 - val_y1_output_root_mean_squared_error: 0.9582 - val_y2_output_root_mean_squared_error: 1.9361
# Epoch 115/500
# 614/614 [==============================] - 0s 122us/sample - loss: 1.8962 - y1_output_loss: 0.4883 - y2_output_loss: 1.4225 - y1_output_root_mean_squared_error: 0.6941 - y2_output_root_mean_squared_error: 1.1893 - val_loss: 3.4339 - val_y1_output_loss: 0.5261 - val_y2_output_loss: 2.8443 - val_y1_output_root_mean_squared_error: 0.7375 - val_y2_output_root_mean_squared_error: 1.7000
# Epoch 116/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.4523 - y1_output_loss: 0.5043 - y2_output_loss: 1.9489 - y1_output_root_mean_squared_error: 0.7103 - y2_output_root_mean_squared_error: 1.3956 - val_loss: 4.8245 - val_y1_output_loss: 0.5132 - val_y2_output_loss: 4.1551 - val_y1_output_root_mean_squared_error: 0.7191 - val_y2_output_root_mean_squared_error: 2.0754
# Epoch 117/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.0827 - y1_output_loss: 0.4190 - y2_output_loss: 1.6507 - y1_output_root_mean_squared_error: 0.6501 - y2_output_root_mean_squared_error: 1.2884 - val_loss: 3.1434 - val_y1_output_loss: 0.3742 - val_y2_output_loss: 2.6719 - val_y1_output_root_mean_squared_error: 0.6105 - val_y2_output_root_mean_squared_error: 1.6645
# Epoch 118/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.0350 - y1_output_loss: 0.4483 - y2_output_loss: 1.5798 - y1_output_root_mean_squared_error: 0.6721 - y2_output_root_mean_squared_error: 1.2583 - val_loss: 3.6490 - val_y1_output_loss: 0.4472 - val_y2_output_loss: 3.1330 - val_y1_output_root_mean_squared_error: 0.6811 - val_y2_output_root_mean_squared_error: 1.7847
# Epoch 119/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.2054 - y1_output_loss: 0.5120 - y2_output_loss: 1.6810 - y1_output_root_mean_squared_error: 0.7143 - y2_output_root_mean_squared_error: 1.3020 - val_loss: 2.5561 - val_y1_output_loss: 0.4165 - val_y2_output_loss: 2.0579 - val_y1_output_root_mean_squared_error: 0.6554 - val_y2_output_root_mean_squared_error: 1.4583
# Epoch 120/500
# 614/614 [==============================] - 0s 123us/sample - loss: 1.7765 - y1_output_loss: 0.4016 - y2_output_loss: 1.3689 - y1_output_root_mean_squared_error: 0.6348 - y2_output_root_mean_squared_error: 1.1720 - val_loss: 5.7694 - val_y1_output_loss: 1.0675 - val_y2_output_loss: 4.6320 - val_y1_output_root_mean_squared_error: 1.0465 - val_y2_output_root_mean_squared_error: 2.1620
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3782 - y1_output_loss: 0.1303 - y2_output_loss: 0.2478 - y1_output_root_mean_squared_error: 0.3601 - y2_output_root_mean_squared_error: 0.4986 - val_loss: 1.3176 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 1.0583 - val_y1_output_root_mean_squared_error: 0.4722 - val_y2_output_root_mean_squared_error: 1.0462
# Epoch 462/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3940 - y1_output_loss: 0.1272 - y2_output_loss: 0.2689 - y1_output_root_mean_squared_error: 0.3567 - y2_output_root_mean_squared_error: 0.5165 - val_loss: 1.6292 - val_y1_output_loss: 0.4327 - val_y2_output_loss: 1.1748 - val_y1_output_root_mean_squared_error: 0.6622 - val_y2_output_root_mean_squared_error: 1.0912
# Epoch 463/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4596 - y1_output_loss: 0.1592 - y2_output_loss: 0.2971 - y1_output_root_mean_squared_error: 0.3997 - y2_output_root_mean_squared_error: 0.5476 - val_loss: 0.9702 - val_y1_output_loss: 0.1483 - val_y2_output_loss: 0.7897 - val_y1_output_root_mean_squared_error: 0.3894 - val_y2_output_root_mean_squared_error: 0.9047
# Epoch 464/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3438 - y1_output_loss: 0.1093 - y2_output_loss: 0.2329 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.4833 - val_loss: 0.9558 - val_y1_output_loss: 0.1739 - val_y2_output_loss: 0.7567 - val_y1_output_root_mean_squared_error: 0.4197 - val_y2_output_root_mean_squared_error: 0.8830
# Epoch 465/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.4044 - y1_output_loss: 0.1371 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3650 - y2_output_root_mean_squared_error: 0.5208 - val_loss: 1.7761 - val_y1_output_loss: 0.3491 - val_y2_output_loss: 1.3875 - val_y1_output_root_mean_squared_error: 0.5989 - val_y2_output_root_mean_squared_error: 1.1905
# Epoch 466/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5593 - y1_output_loss: 0.1451 - y2_output_loss: 0.4119 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.6430 - val_loss: 0.9962 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.7903 - val_y1_output_root_mean_squared_error: 0.4235 - val_y2_output_root_mean_squared_error: 0.9038
# Epoch 467/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3946 - y1_output_loss: 0.1300 - y2_output_loss: 0.2620 - y1_output_root_mean_squared_error: 0.3620 - y2_output_root_mean_squared_error: 0.5134 - val_loss: 1.1620 - val_y1_output_loss: 0.2208 - val_y2_output_loss: 0.9027 - val_y1_output_root_mean_squared_error: 0.4778 - val_y2_output_root_mean_squared_error: 0.9663
# Epoch 468/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3136 - y1_output_loss: 0.1148 - y2_output_loss: 0.1974 - y1_output_root_mean_squared_error: 0.3404 - y2_output_root_mean_squared_error: 0.4447 - val_loss: 0.9217 - val_y1_output_loss: 0.1368 - val_y2_output_loss: 0.7550 - val_y1_output_root_mean_squared_error: 0.3739 - val_y2_output_root_mean_squared_error: 0.8842
# Epoch 469/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4099 - y1_output_loss: 0.1225 - y2_output_loss: 0.2873 - y1_output_root_mean_squared_error: 0.3482 - y2_output_root_mean_squared_error: 0.5373 - val_loss: 1.2689 - val_y1_output_loss: 0.2575 - val_y2_output_loss: 0.9680 - val_y1_output_root_mean_squared_error: 0.5149 - val_y2_output_root_mean_squared_error: 1.0019
# Epoch 470/500
# 614/614 [==============================] - 0s 119us/sample - loss: 0.4177 - y1_output_loss: 0.1257 - y2_output_loss: 0.2889 - y1_output_root_mean_squared_error: 0.3561 - y2_output_root_mean_squared_error: 0.5393 - val_loss: 0.9403 - val_y1_output_loss: 0.1616 - val_y2_output_loss: 0.7475 - val_y1_output_root_mean_squared_error: 0.4078 - val_y2_output_root_mean_squared_error: 0.8798
# Epoch 471/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4036 - y1_output_loss: 0.1252 - y2_output_loss: 0.2754 - y1_output_root_mean_squared_error: 0.3542 - y2_output_root_mean_squared_error: 0.5274 - val_loss: 1.0864 - val_y1_output_loss: 0.1635 - val_y2_output_loss: 0.8910 - val_y1_output_root_mean_squared_error: 0.4063 - val_y2_output_root_mean_squared_error: 0.9598
# Epoch 472/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3702 - y1_output_loss: 0.1197 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3468 - y2_output_root_mean_squared_error: 0.4999 - val_loss: 1.1344 - val_y1_output_loss: 0.1999 - val_y2_output_loss: 0.9014 - val_y1_output_root_mean_squared_error: 0.4481 - val_y2_output_root_mean_squared_error: 0.9662
# Epoch 473/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3473 - y1_output_loss: 0.1147 - y2_output_loss: 0.2313 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 0.9527 - val_y1_output_loss: 0.1766 - val_y2_output_loss: 0.7440 - val_y1_output_root_mean_squared_error: 0.4269 - val_y2_output_root_mean_squared_error: 0.8778
# Epoch 474/500
# 614/614 [==============================] - 0s 118us/sample - loss: 0.3408 - y1_output_loss: 0.1133 - y2_output_loss: 0.2260 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.4764 - val_loss: 1.0039 - val_y1_output_loss: 0.1518 - val_y2_output_loss: 0.8287 - val_y1_output_root_mean_squared_error: 0.3916 - val_y2_output_root_mean_squared_error: 0.9223
# Epoch 475/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.3342 - y1_output_loss: 0.1137 - y2_output_loss: 0.2222 - y1_output_root_mean_squared_error: 0.3371 - y2_output_root_mean_squared_error: 0.4696 - val_loss: 1.0390 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 0.7672 - val_y1_output_root_mean_squared_error: 0.4990 - val_y2_output_root_mean_squared_error: 0.8888
# Epoch 476/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3465 - y1_output_loss: 0.1240 - y2_output_loss: 0.2235 - y1_output_root_mean_squared_error: 0.3518 - y2_output_root_mean_squared_error: 0.4719 - val_loss: 1.2526 - val_y1_output_loss: 0.2175 - val_y2_output_loss: 1.0001 - val_y1_output_root_mean_squared_error: 0.4741 - val_y2_output_root_mean_squared_error: 1.0138
# Epoch 477/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4169 - y1_output_loss: 0.1240 - y2_output_loss: 0.2908 - y1_output_root_mean_squared_error: 0.3524 - y2_output_root_mean_squared_error: 0.5410 - val_loss: 1.3388 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 1.0680 - val_y1_output_root_mean_squared_error: 0.4893 - val_y2_output_root_mean_squared_error: 1.0485
# Epoch 478/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6355 - y1_output_loss: 0.1549 - y2_output_loss: 0.4879 - y1_output_root_mean_squared_error: 0.3934 - y2_output_root_mean_squared_error: 0.6933 - val_loss: 1.3075 - val_y1_output_loss: 0.2243 - val_y2_output_loss: 1.0632 - val_y1_output_root_mean_squared_error: 0.4727 - val_y2_output_root_mean_squared_error: 1.0412
# Epoch 479/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3858 - y1_output_loss: 0.1208 - y2_output_loss: 0.2662 - y1_output_root_mean_squared_error: 0.3486 - y2_output_root_mean_squared_error: 0.5140 - val_loss: 1.6715 - val_y1_output_loss: 0.3039 - val_y2_output_loss: 1.3341 - val_y1_output_root_mean_squared_error: 0.5567 - val_y2_output_root_mean_squared_error: 1.1669
# Epoch 480/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.5542 - y1_output_loss: 0.1520 - y2_output_loss: 0.3980 - y1_output_root_mean_squared_error: 0.3906 - y2_output_root_mean_squared_error: 0.6337 - val_loss: 1.0218 - val_y1_output_loss: 0.1972 - val_y2_output_loss: 0.7911 - val_y1_output_root_mean_squared_error: 0.4505 - val_y2_output_root_mean_squared_error: 0.9049
# Epoch 481/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.5598 - y1_output_loss: 0.1402 - y2_output_loss: 0.4194 - y1_output_root_mean_squared_error: 0.3751 - y2_output_root_mean_squared_error: 0.6474 - val_loss: 1.3813 - val_y1_output_loss: 0.2504 - val_y2_output_loss: 1.0849 - val_y1_output_root_mean_squared_error: 0.5088 - val_y2_output_root_mean_squared_error: 1.0595
# Epoch 482/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3501 - y1_output_loss: 0.1305 - y2_output_loss: 0.2184 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.4684 - val_loss: 1.0595 - val_y1_output_loss: 0.1514 - val_y2_output_loss: 0.8740 - val_y1_output_root_mean_squared_error: 0.3952 - val_y2_output_root_mean_squared_error: 0.9504
# Epoch 483/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4755 - y1_output_loss: 0.1310 - y2_output_loss: 0.3416 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.5865 - val_loss: 0.9372 - val_y1_output_loss: 0.1312 - val_y2_output_loss: 0.7757 - val_y1_output_root_mean_squared_error: 0.3654 - val_y2_output_root_mean_squared_error: 0.8965
# Epoch 484/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4739 - y1_output_loss: 0.1149 - y2_output_loss: 0.3559 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.5992 - val_loss: 0.9988 - val_y1_output_loss: 0.1821 - val_y2_output_loss: 0.7842 - val_y1_output_root_mean_squared_error: 0.4314 - val_y2_output_root_mean_squared_error: 0.9015
# Epoch 485/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4108 - y1_output_loss: 0.1333 - y2_output_loss: 0.2783 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.5288 - val_loss: 1.0790 - val_y1_output_loss: 0.1873 - val_y2_output_loss: 0.8569 - val_y1_output_root_mean_squared_error: 0.4394 - val_y2_output_root_mean_squared_error: 0.9412
# Epoch 486/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3503 - y1_output_loss: 0.1091 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.4902 - val_loss: 1.0295 - val_y1_output_loss: 0.1643 - val_y2_output_loss: 0.8341 - val_y1_output_root_mean_squared_error: 0.4108 - val_y2_output_root_mean_squared_error: 0.9277
# Epoch 487/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3618 - y1_output_loss: 0.1128 - y2_output_loss: 0.2480 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.5001 - val_loss: 1.0470 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.7860 - val_y1_output_root_mean_squared_error: 0.4810 - val_y2_output_root_mean_squared_error: 0.9031
# Epoch 488/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6377 - y1_output_loss: 0.1843 - y2_output_loss: 0.4494 - y1_output_root_mean_squared_error: 0.4303 - y2_output_root_mean_squared_error: 0.6727 - val_loss: 1.0100 - val_y1_output_loss: 0.1764 - val_y2_output_loss: 0.8014 - val_y1_output_root_mean_squared_error: 0.4258 - val_y2_output_root_mean_squared_error: 0.9103
# Epoch 489/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3101 - y1_output_loss: 0.0991 - y2_output_loss: 0.2125 - y1_output_root_mean_squared_error: 0.3154 - y2_output_root_mean_squared_error: 0.4589 - val_loss: 1.0837 - val_y1_output_loss: 0.1522 - val_y2_output_loss: 0.9005 - val_y1_output_root_mean_squared_error: 0.3955 - val_y2_output_root_mean_squared_error: 0.9629
# Epoch 490/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3669 - y1_output_loss: 0.1090 - y2_output_loss: 0.2606 - y1_output_root_mean_squared_error: 0.3238 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 1.0247 - val_y1_output_loss: 0.2168 - val_y2_output_loss: 0.7755 - val_y1_output_root_mean_squared_error: 0.4700 - val_y2_output_root_mean_squared_error: 0.8965
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2973 - y1_output_loss: 0.1077 - y2_output_loss: 0.1883 - y1_output_root_mean_squared_error: 0.3296 - y2_output_root_mean_squared_error: 0.4343 - val_loss: 0.9155 - val_y1_output_loss: 0.1407 - val_y2_output_loss: 0.7444 - val_y1_output_root_mean_squared_error: 0.3800 - val_y2_output_root_mean_squared_error: 0.8781
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2536 - y1_output_loss: 0.0940 - y2_output_loss: 0.1601 - y1_output_root_mean_squared_error: 0.3070 - y2_output_root_mean_squared_error: 0.3992 - val_loss: 1.4438 - val_y1_output_loss: 0.2014 - val_y2_output_loss: 1.2074 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 1.1133
# Epoch 493/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5110 - y1_output_loss: 0.1186 - y2_output_loss: 0.3911 - y1_output_root_mean_squared_error: 0.3455 - y2_output_root_mean_squared_error: 0.6258 - val_loss: 1.4787 - val_y1_output_loss: 0.3321 - val_y2_output_loss: 1.1125 - val_y1_output_root_mean_squared_error: 0.5839 - val_y2_output_root_mean_squared_error: 1.0667
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.4322 - y1_output_loss: 0.1290 - y2_output_loss: 0.3003 - y1_output_root_mean_squared_error: 0.3606 - y2_output_root_mean_squared_error: 0.5497 - val_loss: 1.1484 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.9376 - val_y1_output_root_mean_squared_error: 0.4217 - val_y2_output_root_mean_squared_error: 0.9852
# Epoch 495/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3672 - y1_output_loss: 0.1173 - y2_output_loss: 0.2475 - y1_output_root_mean_squared_error: 0.3434 - y2_output_root_mean_squared_error: 0.4993 - val_loss: 1.0323 - val_y1_output_loss: 0.1837 - val_y2_output_loss: 0.8135 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 0.9187
# Epoch 496/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.3067 - y1_output_loss: 0.1077 - y2_output_loss: 0.1976 - y1_output_root_mean_squared_error: 0.3289 - y2_output_root_mean_squared_error: 0.4456 - val_loss: 0.9670 - val_y1_output_loss: 0.1525 - val_y2_output_loss: 0.7820 - val_y1_output_root_mean_squared_error: 0.3964 - val_y2_output_root_mean_squared_error: 0.8999
# Epoch 497/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2847 - y1_output_loss: 0.1034 - y2_output_loss: 0.1814 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4252 - val_loss: 1.3492 - val_y1_output_loss: 0.1442 - val_y2_output_loss: 1.1653 - val_y1_output_root_mean_squared_error: 0.3826 - val_y2_output_root_mean_squared_error: 1.0967
# Epoch 498/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3340 - y1_output_loss: 0.1090 - y2_output_loss: 0.2248 - y1_output_root_mean_squared_error: 0.3310 - y2_output_root_mean_squared_error: 0.4738 - val_loss: 1.1153 - val_y1_output_loss: 0.1597 - val_y2_output_loss: 0.9176 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 0.9753
# Epoch 499/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3241 - y1_output_loss: 0.1024 - y2_output_loss: 0.2192 - y1_output_root_mean_squared_error: 0.3212 - y2_output_root_mean_squared_error: 0.4701 - val_loss: 1.0180 - val_y1_output_loss: 0.1759 - val_y2_output_loss: 0.8132 - val_y1_output_root_mean_squared_error: 0.4243 - val_y2_output_root_mean_squared_error: 0.9154
# Epoch 500/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3252 - y1_output_loss: 0.1021 - y2_output_loss: 0.2219 - y1_output_root_mean_squared_error: 0.3201 - y2_output_root_mean_squared_error: 0.4720 - val_loss: 0.9793 - val_y1_output_loss: 0.1992 - val_y2_output_loss: 0.7487 - val_y1_output_root_mean_squared_error: 0.4518 - val_y2_output_root_mean_squared_error: 0.8804

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.9793 - y1_output_loss: 0.2032 - y2_output_loss: 0.7679 - y1_output_root_mean_squared_error: 0.4518 - y2_output_root_mean_squared_error: 0.8804
# Loss = 0.9792850211069182, Y1_loss = 0.203231543302536, Y1_mse = 0.45181551575660706, Y2_loss = 0.7679094672203064, Y2_mse = 0.8804247975349426

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
